# %% [markdown]
# # Minds14 audio classification with Wav2vec2 model

# %% [markdown]
# This notebook performs audio classification using the Wav2Vec2 model fine-tuned on the Minds14 dataset.
# We will cover the steps from loading and preprocessing the audio data to training the model and making predictions.

# %% [markdown]
# **You can adopt some models like distilhubert-finetuned-Minds14 to obtain the higher accuracy results.**
# The model might not run in my notebook due to time and cloud storage, but I produced the results locally.

# %% [markdown]
# ## Installation of Required Libraries
# First, ensure all required libraries are installed.

# %%
! pip install transformers datasets evaluate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\feixing\appdata\roaming\python\python312\site-packages (4.46.3)
# Requirement already satisfied: datasets in c:\users\feixing\appdata\roaming\python\python312\site-packages (3.1.0)
# Requirement already satisfied: evaluate in c:\users\feixing\appdata\roaming\python\python312\site-packages (0.4.3)
# Requirement already satisfied: filelock in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from datasets) (18.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\feixing\appdata\roaming\python\python312\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in c:\users\feixing\appdata\roaming\python\python312\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in e:\programdata\anaconda\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\feixing\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\programdata\anaconda\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\programdata\anaconda\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in e:\programdata\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
! pip install evaluate soundfile
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: evaluate in c:\users\feixing\appdata\roaming\python\python312\site-packages (0.4.3)
# Requirement already satisfied: soundfile in c:\users\feixing\appdata\roaming\python\python312\site-packages (0.12.1)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (3.1.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (0.26.2)
# Requirement already satisfied: packaging in c:\users\feixing\appdata\roaming\python\python312\site-packages (from evaluate) (24.2)
# Requirement already satisfied: cffi>=1.0 in e:\programdata\anaconda\lib\site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in e:\programdata\anaconda\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: filelock in c:\users\feixing\appdata\roaming\python\python312\site-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from datasets>=2.0.0->evaluate) (18.0.0)
# Requirement already satisfied: aiohttp in e:\programdata\anaconda\lib\site-packages (from datasets>=2.0.0->evaluate) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\feixing\appdata\roaming\python\python312\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\programdata\anaconda\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\programdata\anaconda\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\feixing\appdata\roaming\python\python312\site-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\programdata\anaconda\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.11.0)
# Requirement already satisfied: six>=1.5 in e:\programdata\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)

# %%
! pip install librosa accelerate>=0.26.0

# %% [markdown]
# ## Load MInDS-14 dataset

# %% [markdown]
# We will use the Minds14 dataset available from the 🤗 datasets library, focusing on the 'en-US' subset for audio classification.

# %%
from datasets import load_dataset, Audio

minds = load_dataset("PolyAI/minds14", name="en-US", split="train", trust_remote_code=True)

# %% [markdown]
# Split the dataset's `train` split into a smaller train and test set.

# %%
minds = minds.train_test_split(test_size=0.2)

# %% [markdown]
# Then take a look at the dataset

# %%
minds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['path', 'audio', 'transcription', 'english_transcription', 'intent_class', 'lang_id'],
#         num_rows: 450
#     })
#     test: Dataset({
#         features: ['path', 'audio', 'transcription', 'english_transcription', 'intent_class', 'lang_id'],
#         num_rows: 113
#     })
# })

# %%
minds["train"][0]
# Out:
# {'path': 'C:\\Users\\Feixing\\.cache\\huggingface\\datasets\\downloads\\extracted\\97d01a83cccb2cf5e353762faba56f0f7c58b404b3594e5510f040b0870a5c0a\\en-US~BUSINESS_LOAN\\602bac4d963e11ccd901cda8.wav',
#  'audio': {'path': 'C:\\Users\\Feixing\\.cache\\huggingface\\datasets\\downloads\\extracted\\97d01a83cccb2cf5e353762faba56f0f7c58b404b3594e5510f040b0870a5c0a\\en-US~BUSINESS_LOAN\\602bac4d963e11ccd901cda8.wav',
#   'array': array([-0.00024414,  0.        , -0.00024414, ...,  0.        ,
#           0.00024414,  0.00024414]),
#   'sampling_rate': 8000},
#  'transcription': "hi I'm an account holder have been for 18 years and I'd like to speak to somebody about taking out a business loan",
#  'english_transcription': "hi I'm an account holder have been for 18 years and I'd like to speak to somebody about taking out a business loan",
#  'intent_class': 5,
#  'lang_id': 4}

# %% [markdown]
# We'll remove unnecessary columns and ensure the audio data is properly formatted for our model.

# %%
minds = minds.remove_columns(["path", "transcription", "english_transcription", "lang_id"])

# %% [markdown]
# Display an example from the dataset to understand the format

# %%
minds["train"][0]
# Out:
# {'audio': {'path': 'C:\\Users\\Feixing\\.cache\\huggingface\\datasets\\downloads\\extracted\\97d01a83cccb2cf5e353762faba56f0f7c58b404b3594e5510f040b0870a5c0a\\en-US~BUSINESS_LOAN\\602bac4d963e11ccd901cda8.wav',
#   'array': array([-0.00024414,  0.        , -0.00024414, ...,  0.        ,
#           0.00024414,  0.00024414]),
#   'sampling_rate': 8000},
#  'intent_class': 5}

# %%
labels = minds["train"].features["intent_class"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

# %% [markdown]
# Now you can convert the label id to a label name:

# %%
id2label[str(2)]
# Out:
# 'app_error'

# %% [markdown]
# ## Preprocess and Feature Extraction

# %% [markdown]
# We'll load the Wav2Vec2 feature extractor and prepare our dataset by extracting features suitable for audio classification.

# %%
from transformers import AutoFeatureExtractor

feature_extractor = AutoFeatureExtractor.from_pretrained("facebook/wav2vec2-base")
# Out:
# C:\Users\Feixing\AppData\Roaming\Python\Python312\site-packages\transformers\configuration_utils.py:306: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(

# %% [markdown]
# Resample the dataset to 16000kHz to use the pretrained Wav2Vec2 model:

# %%
minds = minds.cast_column("audio", Audio(sampling_rate=16_000))
minds["train"][0]
# Out:
# {'audio': {'path': 'C:\\Users\\Feixing\\.cache\\huggingface\\datasets\\downloads\\extracted\\97d01a83cccb2cf5e353762faba56f0f7c58b404b3594e5510f040b0870a5c0a\\en-US~BUSINESS_LOAN\\602bac4d963e11ccd901cda8.wav',
#   'array': array([-1.99531321e-04, -4.72508618e-05, -4.45675541e-05, ...,
#           2.77621846e-04,  2.34195439e-04,  1.25979845e-04]),
#   'sampling_rate': 16000},
#  'intent_class': 5}

# %% [markdown]
# Create a preprocessing function that:

# %%
def preprocess_function(examples):
    audio_arrays = [x["array"] for x in examples["audio"]]
    inputs = feature_extractor(
        audio_arrays, sampling_rate=feature_extractor.sampling_rate, max_length=16000, truncation=True
    )
    return inputs

# %% [markdown]
# To apply the preprocessing function over the entire dataset, use 🤗 Datasets map function.

# %%
encoded_minds = minds.map(preprocess_function, remove_columns="audio", batched=True)
encoded_minds = encoded_minds.rename_column("intent_class", "label")
print(encoded_minds)
# Out:
# Map:   0%|          | 0/450 [00:00<?, ? examples/s]
# Map:   0%|          | 0/113 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_values'],
#         num_rows: 450
#     })
#     test: Dataset({
#         features: ['label', 'input_values'],
#         num_rows: 113
#     })
# })

# %% [markdown]
# ## Evaluate

# %% [markdown]
# Set compute_metrics function

# %%
import evaluate

accuracy = evaluate.load("accuracy")

# %% [markdown]
# Then create a function that passes your predictions and labels to [compute](https://huggingface.co/docs/evaluate/main/en/package_reference/main_classes#evaluate.EvaluationModule.compute) to calculate the accuracy:

# %%
import numpy as np


def compute_metrics(eval_pred):
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=eval_pred.label_ids)

# %% [markdown]
# ## Model Training

# %% [markdown]
# We will now load the pre-trained Wav2Vec2 model and fine-tune it on the Minds14 dataset for audio classification.

# %%
from transformers import AutoFeatureExtractor, AutoModelForAudioClassification, TrainingArguments, Trainer

feature_extractor = AutoFeatureExtractor.from_pretrained("facebook/wav2vec2-base")
num_labels = len(id2label)
model = AutoModelForAudioClassification.from_pretrained(
    "facebook/wav2vec2-base", num_labels=num_labels, label2id=label2id, id2label=id2label
)
print(model)
# Out:
# C:\Users\Feixing\AppData\Roaming\Python\Python312\site-packages\transformers\configuration_utils.py:306: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Wav2Vec2ForSequenceClassification(
#   (wav2vec2): Wav2Vec2Model(
#     (feature_extractor): Wav2Vec2FeatureEncoder(
#       (conv_layers): ModuleList(
#         (0): Wav2Vec2GroupNormConvLayer(
#           (conv): Conv1d(1, 512, kernel_size=(10,), stride=(5,), bias=False)
#           (activation): GELUActivation()
#           (layer_norm): GroupNorm(512, 512, eps=1e-05, affine=True)
#         )
#         (1-4): 4 x Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#         (5-6): 2 x Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#       )
#     )
#     (feature_projection): Wav2Vec2FeatureProjection(
#       (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (projection): Linear(in_features=512, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): Wav2Vec2Encoder(
#       (pos_conv_embed): Wav2Vec2PositionalConvEmbedding(
#         (conv): ParametrizedConv1d(
#           768, 768, kernel_size=(128,), stride=(1,), padding=(64,), groups=16
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (padding): Wav2Vec2SamePadLayer()
#         (activation): GELUActivation()
#       )
#       (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (layers): ModuleList(
#         (0-11): 12 x Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2SdpaAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (projector): Linear(in_features=768, out_features=256, bias=True)
#   (classifier): Linear(in_features=256, out_features=14, bias=True)
# )

# %% [markdown]
# **You can adopt new model like distilhubert-finetuned-Minds14 to obtain the higher accuracy results**

# %%
# Load distilhubert-finetuned-Minds14 model
# from transformers import AutoProcessor, AutoModelForAudioClassification

# processor = AutoProcessor.from_pretrained("Teapack1/distilhubert-finetuned-Minds14")
# model = AutoModelForAudioClassification.from_pretrained("Teapack1/distilhubert-finetuned-Minds14")

# %% [markdown]
# Start to train the model

# %%
# Training arguments
training_args = TrainingArguments(
    output_dir="minds14_wav2vec2",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=16,
    gradient_accumulation_steps=4,
    per_device_eval_batch_size=16,
    num_train_epochs=10,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    report_to="none"  # Disable wandb
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=encoded_minds["train"],
    eval_dataset=encoded_minds["test"],
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# C:\Users\Feixing\AppData\Local\Temp\ipykernel_5564\2972462591.py:18: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='44' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [44/70 16:55 < 10:28, 0.04 it/s, Epoch 5.93/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>2.641577</td>
#       <td>0.070796</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.638900</td>
#       <td>2.643246</td>
#       <td>0.070796</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.629200</td>
#       <td>2.649750</td>
#       <td>0.053097</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.619000</td>
#       <td>2.659642</td>
#       <td>0.053097</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.612300</td>
#       <td>2.681885</td>
#       <td>0.053097</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\serialization.py:850, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     849 with _open_zipfile_writer(f) as opened_zipfile:
# --> 850     _save(
#     851         obj,
#     852         opened_zipfile,
#     853         pickle_module,
#     854         pickle_protocol,
#     855         _disable_byteorder_record,
#     856     )
#     857     return
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\serialization.py:1114, in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1113 # Now that it is on the CPU we can directly copy it into the zip file
# -> 1114 zip_file.write_record(name, storage, num_bytes)
#
# RuntimeError: [enforce fail at inline_container.cc:783] . PytorchStreamWriter failed writing file data/125: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 27
#       2 training_args = TrainingArguments(
#       3     output_dir="minds14_wav2vec2",
#       4     eval_strategy="epoch",
#    (...)
#      15     report_to="none"  # Disable wandb
#      16 )
#      18 trainer = Trainer(
#      19     model=model,
#      20     args=training_args,
#    (...)
#      24     compute_metrics=compute_metrics,
#      25 )
# ---> 27 trainer.train()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\trainer.py:2123, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2121         hf_hub_utils.enable_progress_bars()
#    2122 else:
# -> 2123     return inner_training_loop(
#    2124         args=args,
#    2125         resume_from_checkpoint=resume_from_checkpoint,
#    2126         trial=trial,
#    2127         ignore_keys_for_eval=ignore_keys_for_eval,
#    2128     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\trainer.py:2573, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2570     self.control.should_training_stop = True
#    2572 self.control = self.callback_handler.on_epoch_end(args, self.state, self.control)
# -> 2573 self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2575 if DebugOption.TPU_METRICS_DEBUG in self.args.debug:
#    2576     if is_torch_xla_available():
#    2577         # tpu-comment: Logging debug metrics for PyTorch/XLA (compile, execute times, ops, etc.)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\trainer.py:3007, in Trainer._maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    3004     metrics = self._evaluate(trial, ignore_keys_for_eval)
#    3006 if self.control.should_save:
# -> 3007     self._save_checkpoint(model, trial, metrics=metrics)
#    3008     self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\trainer.py:3101, in Trainer._save_checkpoint(self, model, trial, metrics)
#    3097 self.save_model(output_dir, _internal_call=True)
#    3099 if not self.args.save_only_model:
#    3100     # Save optimizer and scheduler
# -> 3101     self._save_optimizer_and_scheduler(output_dir)
#    3102     # Save RNG state
#    3103     self._save_rng_state(output_dir)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\trainer.py:3247, in Trainer._save_optimizer_and_scheduler(self, output_dir)
#    3242     save_fsdp_optimizer(
#    3243         self.accelerator.state.fsdp_plugin, self.accelerator, self.optimizer, self.model, output_dir
#    3244     )
#    3245 elif self.args.should_save:
#    3246     # deepspeed.save_checkpoint above saves model/optim/sched
# -> 3247     torch.save(self.optimizer.state_dict(), os.path.join(output_dir, OPTIMIZER_NAME))
#    3249 # Save SCHEDULER & SCALER
#    3250 is_deepspeed_custom_scheduler = self.is_deepspeed_enabled and not isinstance(
#    3251     self.lr_scheduler, DeepSpeedSchedulerWrapper
#    3252 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\serialization.py:849, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     846 _check_save_filelike(f)
#     848 if _use_new_zipfile_serialization:
# --> 849     with _open_zipfile_writer(f) as opened_zipfile:
#     850         _save(
#     851             obj,
#     852             opened_zipfile,
#    (...)
#     855             _disable_byteorder_record,
#     856         )
#     857         return
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\serialization.py:690, in _open_zipfile_writer_file.__exit__(self, *args)
#     689 def __exit__(self, *args) -> None:
# --> 690     self.file_like.write_end_of_file()
#     691     if self.file_stream is not None:
#     692         self.file_stream.close()
#
# RuntimeError: [enforce fail at inline_container.cc:603] . unexpected pos 96001216 vs 96001104

# %% [markdown]
# ## Inference

# %% [markdown]
# After training, let's use our fine-tuned model to predict new audio samples.

# %%
# Example of predicting a single audio file
test_audio = encoded_minds["test"][12]["input_values"]  # Simulating loading a test audio file
test_audio_tensor = torch.tensor(test_audio)
# Predicting using the trained model
model.eval()
with torch.no_grad():
    logits = model(test_audio_tensor.unsqueeze(0)).logits  # Unsqueeze batch dimension
predicted_label = logits.argmax(-1).item()

print("Predicted class for the test audio:", predicted_label)
print("Real class for the test audio:", encoded_minds["test"][12]["label"])
# Out:
# Predicted class for the test audio: 3
# Real class for the test audio: 7

# %% [markdown]
# This model is not accurate based on minds14 dataset.
